# %%
import pandas as pd
import numpy as np


## one way ANOVA test
import statsmodels
import statsmodels.api as sm
from statsmodels.formula.api import ols


## model
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

# %%
data = pd.read_csv("withtax.csv")
data = data.rename(columns={"GEO.id2": "id2"})
data.head()
# Out:
#      id2          GEO.id      City State  $1 under $25,000  \
# 0  10001  8610000US10001  New York    NY             11690
# 1  10001  8610000US10001  New York    NY             11690
# 2  10001  8610000US10001  New York    NY             11690
# 3  10001  8610000US10001  New York    NY             11690
# 4  10001  8610000US10001  New York    NY             11690
#
#    $100,000 under $200,000  $75,000 under $100,000  $200,000 or more  \
# 0                   227126                   82593           1057880
# 1                   227126                   82593           1057880
# 2                   227126                   82593           1057880
# 3                   227126                   82593           1057880
# 4                   227126                   82593           1057880
#
#    $25,000 under $50,000  $50,000 under $75,000  ...    A00200  N01000  \
# 0                  58621                  82726  ...  753264.0    1110
# 1                  58621                  82726  ...   31491.0     520
# 2                  58621                  82726  ...   75813.0     440
# 3                  58621                  82726  ...   90708.0     440
# 4                  58621                  82726  ...  233340.0     790
#
#      A01000   A00101  N18425  A18425  N18450  A18450  N18300  A18300
# 0  197999.0  1259128    1590  133338       0       0    1610  149260
# 1    -182.0     4688     160     504     130      79     320    1403
# 2     617.0    22026     460    1566     100      84     580    2651
# 3     660.0    54793     780    4315      70      76     860    5696
# 4    4464.0   256806    1750   23359      70     107    1820   27551
#
# [5 rows x 35 columns]

# %%
subcolumns = ["id2","Establishments not operated for the entire year", "Establishments operated for the entire year", "totalSales", "totalIncome"]
sub_data = data[data.columns[-14:]]
sub_data2 = data[subcolumns]
data2 = sub_data2.merge(sub_data, left_on = sub_data2.index, right_on = sub_data.index)
data2 = data2.drop(['key_0'], axis=1) 
data2.head()
# Out:
#      id2  Establishments not operated for the entire year  \
# 0  10001                                               66
# 1  10001                                               66
# 2  10001                                               66
# 3  10001                                               66
# 4  10001                                               66
#
#    Establishments operated for the entire year    totalSales   totalIncome  \
# 0                                         2225  3.566625e+09  5.331146e+13
# 1                                         2225  3.566625e+09  5.331146e+13
# 2                                         2225  3.566625e+09  5.331146e+13
# 3                                         2225  3.566625e+09  5.331146e+13
# 4                                         2225  3.566625e+09  5.331146e+13
#
#    AGI_STUB    N1   A00100  N00200    A00200  N01000    A01000   A00101  \
# 0         6  1650  1275646    1470  753264.0    1110  197999.0  1259128
# 1         1  4080    46886    2570   31491.0     520    -182.0     4688
# 2         2  2520    93346    2160   75813.0     440     617.0    22026
# 3         3  1790   110732    1580   90708.0     440     660.0    54793
# 4         5  2030   282904    1820  233340.0     790    4464.0   256806
#
#    N18425  A18425  N18450  A18450  N18300  A18300
# 0    1590  133338       0       0    1610  149260
# 1     160     504     130      79     320    1403
# 2     460    1566     100      84     580    2651
# 3     780    4315      70      76     860    5696
# 4    1750   23359      70     107    1820   27551

# %%
data2 = data2.rename(columns={"Establishments not operated for the entire year": "estNotEntireYear", "Establishments operated for the entire year":"estEntireYear"}) 
data2.head()
# Out:
#      id2  estNotEntireYear  estEntireYear    totalSales   totalIncome  \
# 0  10001                66           2225  3.566625e+09  5.331146e+13
# 1  10001                66           2225  3.566625e+09  5.331146e+13
# 2  10001                66           2225  3.566625e+09  5.331146e+13
# 3  10001                66           2225  3.566625e+09  5.331146e+13
# 4  10001                66           2225  3.566625e+09  5.331146e+13
#
#    AGI_STUB    N1   A00100  N00200    A00200  N01000    A01000   A00101  \
# 0         6  1650  1275646    1470  753264.0    1110  197999.0  1259128
# 1         1  4080    46886    2570   31491.0     520    -182.0     4688
# 2         2  2520    93346    2160   75813.0     440     617.0    22026
# 3         3  1790   110732    1580   90708.0     440     660.0    54793
# 4         5  2030   282904    1820  233340.0     790    4464.0   256806
#
#    N18425  A18425  N18450  A18450  N18300  A18300
# 0    1590  133338       0       0    1610  149260
# 1     160     504     130      79     320    1403
# 2     460    1566     100      84     580    2651
# 3     780    4315      70      76     860    5696
# 4    1750   23359      70     107    1820   27551

# %%
column_names = list(data2.columns)
for i in range(1,len(column_names)): 
    column_i= column_names[i] 
    formula_str = 'id2' + '~' + column_i
    data_lm = ols(formula_str,data = data2).fit()
    table = sm.stats.anova_lm(data_lm, typ=2)
    print(table)
# Out:
#                         sum_sq        df           F         PR(>F)
# estNotEntireYear  3.281498e+11       1.0  546.564826  1.347338e-120
# Residual          6.904078e+13  114994.0         NaN            NaN
#                      sum_sq        df           F        PR(>F)
# estEntireYear  1.719795e+11       1.0  285.801823  4.884909e-64
# Residual       6.919695e+13  114994.0         NaN           NaN
#                   sum_sq        df           F         PR(>F)
# totalSales  2.829639e+11       1.0  470.995109  3.154958e-104
# Residual    6.908597e+13  114994.0         NaN            NaN
#                    sum_sq        df          F         PR(>F)
# totalIncome  4.953609e+11       1.0  827.07394  3.091395e-181
# Residual     6.887357e+13  114994.0        NaN            NaN
#                 sum_sq        df             F  PR(>F)
# AGI_STUB  9.023929e-20       1.0  1.495911e-28     1.0
# Residual  6.936893e+13  114994.0           NaN     NaN
#                 sum_sq        df         F         PR(>F)
# N1        3.608444e+11       1.0  601.3055  1.910602e-132
# Residual  6.900809e+13  114994.0       NaN            NaN
#                 sum_sq        df           F        PR(>F)
# A00100    2.031110e+11       1.0  337.689066  2.607645e-75
# Residual  6.916582e+13  114994.0         NaN           NaN
#                 sum_sq        df          F         PR(>F)
# N00200    4.042128e+11       1.0  673.99741  3.620761e-148
# Residual  6.896472e+13  114994.0        NaN            NaN
#                 sum_sq        df          F         PR(>F)
# A00200    3.491375e+11       1.0  581.69863  3.342701e-128
# Residual  6.901979e+13  114994.0        NaN            NaN
#                 sum_sq        df           F         PR(>F)
# N01000    4.240501e+11       1.0  707.278342  2.315838e-155
# Residual  6.894488e+13  114994.0         NaN            NaN
#                 sum_sq        df          F        PR(>F)
# A01000    1.553819e+10       1.0  25.763685  3.864810e-07
# Residual  6.935339e+13  114994.0        NaN           NaN
#                 sum_sq        df           F        PR(>F)
# A00101    8.300517e+10       1.0  137.763856  8.558506e-32
# Residual  6.928593e+13  114994.0         NaN           NaN
#                 sum_sq        df          F    PR(>F)
# N18425    1.371219e+10       1.0  22.735421  0.000002
# Residual  6.935522e+13  114994.0        NaN       NaN
#                 sum_sq        df        F    PR(>F)
# A18425    2.906992e+07       1.0  0.04819  0.826244
# Residual  6.936890e+13  114994.0      NaN       NaN
#                 sum_sq        df            F  PR(>F)
# N18450    2.274365e+12       1.0  3898.055127     0.0
# Residual  6.709457e+13  114994.0          NaN     NaN
#                 sum_sq        df            F  PR(>F)
# A18450    1.936238e+12       1.0  3301.895982     0.0
# Residual  6.743269e+13  114994.0          NaN     NaN
#                 sum_sq        df           F         PR(>F)
# N18300    3.033842e+11       1.0  505.134026  1.264978e-111
# Residual  6.906555e+13  114994.0         NaN            NaN
#                 sum_sq        df          F        PR(>F)
# A18300    1.490876e+10       1.0  24.719806  6.639450e-07
# Residual  6.935402e+13  114994.0        NaN           NaN

# %%
## DROP LAST ONE
data2 = data2.drop(columns = ['AGI_STUB','A18425'])
data2.head()
# Out:
#      id2  estNotEntireYear  estEntireYear    totalSales   totalIncome    N1  \
# 0  10001                66           2225  3.566625e+09  5.331146e+13  1650
# 1  10001                66           2225  3.566625e+09  5.331146e+13  4080
# 2  10001                66           2225  3.566625e+09  5.331146e+13  2520
# 3  10001                66           2225  3.566625e+09  5.331146e+13  1790
# 4  10001                66           2225  3.566625e+09  5.331146e+13  2030
#
#     A00100  N00200    A00200  N01000    A01000   A00101  N18425  N18450  \
# 0  1275646    1470  753264.0    1110  197999.0  1259128    1590       0
# 1    46886    2570   31491.0     520    -182.0     4688     160     130
# 2    93346    2160   75813.0     440     617.0    22026     460     100
# 3   110732    1580   90708.0     440     660.0    54793     780      70
# 4   282904    1820  233340.0     790    4464.0   256806    1750      70
#
#    A18450  N18300  A18300
# 0       0    1610  149260
# 1      79     320    1403
# 2      84     580    2651
# 3      76     860    5696
# 4     107    1820   27551

# %%
## 50 percent sampled
## in which 60 percent as train, 20 percent as validate, 20 percent as test
data2 = pd.DataFrame.dropna(data2)
n = int(len(data)*0.5)
data_sampled = data.sample(n)
n = len(data_sampled)
print(n)
train_data = data_sampled.sample(int(n*0.8))
print(len(train_data)) ## 80%
test_data = data_sampled[(data_sampled.index).isin(train_data.index) == False]
print(len(test_data)) ## 20%
validate_data = train_data.sample(int(n*0.2))
print(len(validate_data)) ## 20%
train_data = train_data[(train_data.index).isin(validate_data.index) == False]
print(len(train_data)) ## 60%
# Out:
# 57498
# 45998
# 11500
# 11499
# 34499

# %%
############################ model fitting and testing ##########################

# %%
x_train = train_data.iloc[:, 4:].to_numpy()
y_train = train_data.iloc[:, 0].to_numpy()
x_test = test_data.iloc[:, 4:].to_numpy()
y_test = test_data.iloc[:, 0].to_numpy()
x_val = validate_data.iloc[:, 4:].to_numpy()
y_val = validate_data.iloc[:, 0].to_numpy()

# %%
from sklearn.preprocessing import StandardScaler

sc_X = StandardScaler()
x_train = sc_X.fit_transform(x_train)
x_test = sc_X.fit_transform(x_test)
x_val = sc_X.fit_transform(x_val)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
clf = RandomForestClassifier(n_estimators = 5)
cross_val_score(clf, x_train, y_train, cv = 3)
# Out:
# /Users/harrisonlee/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:657: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=3.
#   % (min_groups, self.n_splits)), Warning)
# array([0.41583725, 0.6137931 , 0.8099123 ])

# %%
print(np.mean(np.array([0.41583725, 0.6137931 , 0.8099123 ])))
# Out:
# 0.6131808833333333

# %%
rfc = RandomForestClassifier(n_estimators = 5)
rfc.fit(x_train,y_train)
print("acc: ",rfc.score(x_test,y_test))
# Out:
# acc:  0.34730434782608693

# %%
for name, importance in zip(column_names[1:], rfc.feature_importances_):
    print(name, "=", importance)
# Out:
# estNotEntireYear = 0.06070041319770342
# estEntireYear = 0.05641984477218112
# totalSales = 0.058436057488147515
# totalIncome = 0.03835106650337015
# AGI_STUB = 0.060549783379777275
# N1 = 0.06024760783010358
# A00100 = 0.044552669338157116
# N00200 = 0.03211611841828
# A00200 = 0.028122894714418405
# N01000 = 0.03966435144605532
# A01000 = 0.03415644866164167
# A00101 = 0.03661556212483653
# N18425 = 0.03938276700731711
# A18425 = 0.04160205944293978
# N18450 = 0.04900383034082705
# A18450 = 0.06107523618296745
# N18300 = 0.060404641993691194
# A18300 = 0.008792367037457113
